# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))
train_df
# Out:
#        Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0           57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1          141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2          321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3           11778   11778     3000.0    0.1240       100.22           RENT
# 4          169382  169382    30000.0    0.1612      1056.49       MORTGAGE
# ...           ...     ...        ...       ...          ...            ...
# 12175      354912  354912    19975.0    0.2565       801.09           RENT
# 12176      354944  354944    15000.0    0.1774       540.34           RENT
# 12177      354973  354973     3600.0    0.1862       131.28           RENT
# 12178      355002  355002    15000.0    0.0881       475.68       MORTGAGE
# 12179      355307  355307    15000.0    0.1774       540.34           RENT
#
#        annual_inc verification_status loan_status pymnt_plan  ...  \
# ...

# %%
# Convert categorical data to numeric and separate target feature for training data
train1 = train_df.drop('target', axis=1)
train2 = train_df['target']
train3 = pd.get_dummies(train1)
train4 = LabelEncoder().fit_transform(train2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-9f07673b2d58> in <module>
#       1 # Convert categorical data to numeric and separate target feature for training data
# ----> 2 train1 = train_df.drop('target', axis=1)
#       3 train2 = train_df['target']
#       4 train3 = pd.get_dummies(train1)
#       5 train4 = LabelEncoder().fit_transform(train2)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
# ...

# %%
# Convert categorical data to numeric and separate target feature for testing data
test1 = train_df.drop('target', axis=1)
test2 = train_df['target']
test3 = pd.get_dummies(test1)
test4 = LabelEncoder().fit_transform(test2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-1adb93673ea1> in <module>
#       1 # Convert categorical data to numeric and separate target feature for testing data
# ----> 2 test1 = train_df.drop('target', axis=1)
#       3 test2 = train_df['target']
#       4 test3 = pd.get_dummies(test1)
#       5 test4 = LabelEncoder().fit_transform(test2)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
# add missing dummy variables to testing set
dummy = train3.columns
dummy2 = test3.columns
missing = set(dummy).symmetric_difference(dummy2)
for col in missing:
    train3[col] = 0
columns = list(train3.columns.values)
train3= train3[columns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-6f58d4b4acd6> in <module>
#       1 # add missing dummy variables to testing set
# ----> 2 dummy = train3.columns
#       3 dummy2 = test3.columns
#       4 missing = set(dummy).symmetric_difference(dummy2)
#       5 for col in missing:
#
# NameError: name 'train3' is not defined

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
unscaled = LogisticRegression(max_iter=8000)
unscaled.fit(train3, train4)
print(f"Training Data: {unscaled.score(train3, train4)}")
print(f"Testing Data: {unscaled.score(train3, train4)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-29f886083374> in <module>
#       1 # Train the Logistic Regression model on the unscaled data and print the model score
#       2 unscaled = LogisticRegression(max_iter=8000)
# ----> 3 unscaled.fit(train3, train4)
#       4
#       5 print(f"Training Data: {unscaled.score(train3, train4)}")
#
# NameError: name 'train3' is not defined

# %%
# Train a Random Forest Classifier model and print the model score
unscaled_forest = RandomForestClassifier(random_state=1, n_estimators=500)
unscaled_forest.fit(train3, train4)
print(f"Training Data Score: {unscaled_forest.score(train3, train4)}")
print(f"Testing Data Score: {unscaled_forest.score(train3, train4)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-af06c6f0a507> in <module>
#       1 # Train a Random Forest Classifier model and print the model score
#       2 unscaled_forest = RandomForestClassifier(random_state=1, n_estimators=500)
# ----> 3 unscaled_forest.fit(train3, train4)
#       4 print(f"Training Data Score: {unscaled_forest.score(train3, train4)}")
#       5 print(f"Testing Data Score: {unscaled_forest.score(train3, train4)}")
#
# NameError: name 'train3' is not defined

# %%
# Scale the data
train3_scaled = train3.copy()
test3_scaled = test3.copy()
nums = train_df.select_dtypes(include=np.number).columns.tolist()
unscaled_train = train3_scaled[nums]
unscaled_test = test4_scaled[nums]
scale = StandardScaler().fit(nums.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-d77176526d72> in <module>
#       1 # Scale the data
# ----> 2 train3_scaled = train3.copy()
#       3 test3_scaled = test3.copy()
#       4 nums = train_df.select_dtypes(include=np.number).columns.tolist()
#       5 unscaled_train = train3_scaled[nums]
#
# NameError: name 'train3' is not defined

# %%
# Train the Logistic Regression model on the scaled data and print the model score
scaled_data = LogisticRegression(max_iter=7000)
scaled_data.fit(train3_scaled, train4)
print(f"Training Data Score: {log_scaled.score(train3_scaled, train4)}")
print(f"Testing Data Score: {log_scaled.score(test3_scaled, test4)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-80909cb9ece5> in <module>
#       1 # Train the Logistic Regression model on the scaled data and print the model score
#       2 scaled_data = LogisticRegression(max_iter=7000)
# ----> 3 scaled_data.fit(train3_scaled, train4)
#       4 print(f"Training Data Score: {log_scaled.score(train3_scaled, train4)}")
#       5 print(f"Testing Data Score: {log_scaled.score(test3_scaled, test4)}")
#
# NameError: name 'train3_scaled' is not defined

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
scaled_data = RandomForestClassifier(random_state=1, n_estimators=800)
scaled_data.fit(train3_scaled, train4)
print(f"Training Data Score: {scaled_data.score(train3_scaled, train4)}")
print(f"Testing Data Score: {scaled_data.score(test3_scaled, test4)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-dd5955fc924e> in <module>
#       1 # Train a Random Forest Classifier model on the scaled data and print the model score
#       2 scaled_data = RandomForestClassifier(random_state=1, n_estimators=800)
# ----> 3 scaled_data.fit(train3_scaled, train4)
#       4 print(f"Training Data Score: {scaled_data.score(train3_scaled, train4)}")
#       5 print(f"Testing Data Score: {scaled_data.score(test3_scaled, test4)}")
#
# NameError: name 'train3_scaled' is not defined
